# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
train_data = pd.read_csv("titanic_train.csv")

# %%
test_data = pd.read_csv("titanic_test.csv")

# %%
train_data
# Out:
#      Pclass                                               Name     Sex    Age  \
# 0         2      Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.00
# 1         3                  Williams, Mr. Howard Hugh "Harry"    male    NaN
# 2         2     Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.00
# 3         3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.00
# 4         3                             Sutehall, Mr. Henry Jr    male  25.00
# 5         3                         Lemberopolous, Mr. Peter L    male  34.50
# 6         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00
# 7         3                                 Jonkoff, Mr. Lalio    male  23.00
# 8         2                       Williams, Mr. Charles Eugene    male    NaN
# 9         3                           Rouse, Mr. Richard Henry    male  50.00
# 10        3                    Stanley, Miss. Amy Zillah Elsie  female  23.00
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
train_data.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare    Survived
# count  668.000000  536.000000  668.000000  668.000000  668.000000  668.000000
# mean     2.296407   29.700560    0.528443    0.407186   32.064552    0.402695
# std      0.831638   14.240257    1.080327    0.854695   45.320835    0.490808
# min      1.000000    0.670000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   21.000000    0.000000    0.000000    7.925000    0.000000
# 50%      3.000000   29.000000    0.000000    0.000000   14.750000    0.000000
# 75%      3.000000   38.250000    1.000000    0.000000   31.275000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000

# %%
train_data.Age.fillna(train_data.Age.mean(), inplace = True)

# %%
train_data.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare    Survived
# count  668.000000  668.000000  668.000000  668.000000  668.000000  668.000000
# mean     2.296407   29.700560    0.528443    0.407186   32.064552    0.402695
# std      0.831638   12.753571    1.080327    0.854695   45.320835    0.490808
# min      1.000000    0.670000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   23.000000    0.000000    0.000000    7.925000    0.000000
# 50%      3.000000   29.700560    0.000000    0.000000   14.750000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000   31.275000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000

# %%
train_data.head()
# Out:
#    Pclass                                            Name     Sex       Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.00000
# 1       3               Williams, Mr. Howard Hugh "Harry"    male  29.70056
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.00000
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.00000
# 4       3                          Sutehall, Mr. Henry Jr    male  25.00000
#
#    SibSp  Parch           Ticket    Fare Cabin Embarked  Survived
# 0      1      0           228414  26.000   NaN        S         1
# 1      0      0         A/5 2466   8.050   NaN        S         0
# 2      0      0           250655  26.000   NaN        S         0
# 3      0      4           349909  21.075   NaN        S         0
# 4      0      0  SOTON/OQ 392076   7.050   NaN        S         0

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 11 columns):
# Pclass      668 non-null int64
# Name        668 non-null object
# Sex         668 non-null object
# Age         668 non-null float64
# SibSp       668 non-null int64
# Parch       668 non-null int64
# Ticket      668 non-null object
# Fare        668 non-null float64
# Cabin       154 non-null object
# Embarked    667 non-null object
# Survived    668 non-null int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 57.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train_data['Sex2'] = le.fit_transform(train_data['Sex'])

# %%
train_data['Sex2']
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
# 5      1
# 6      0
# 7      1
# 8      1
# 9      1
# 10     0
# 11     1
# 12     1
# 13     1
# 14     0
# 15     1
# 16     1
# 17     1
# 18     1
# 19     0
# 20     1
# 21     0
# 22     0
# 23     1
# 24     0
# 25     0
# 26     1
# 27     1
# 28     1
# 29     1
#       ..
# 638    1
# 639    0
# 640    0
# 641    1
# 642    1
# 643    1
# 644    1
# 645    1
# 646    0
# 647    1
# 648    1
# 649    1
# 650    1
# 651    1
# 652    0
# 653    0
# 654    1
# 655    1
# 656    1
# 657    1
# 658    0
# 659    1
# 660    1
# 661    0
# 662    1
# 663    0
# 664    1
# 665    1
# 666    0
# 667    0
# Name: Sex2, Length: 668, dtype: int64

# %%
train_data.head()
# Out:
#    Pclass                                            Name     Sex       Age  \
# 0       2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.00000
# 1       3               Williams, Mr. Howard Hugh "Harry"    male  29.70056
# 2       2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.00000
# 3       3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.00000
# 4       3                          Sutehall, Mr. Henry Jr    male  25.00000
#
#    SibSp  Parch           Ticket    Fare Cabin Embarked  Survived  Sex2
# 0      1      0           228414  26.000   NaN        S         1     0
# 1      0      0         A/5 2466   8.050   NaN        S         0     1
# 2      0      0           250655  26.000   NaN        S         0     1
# 3      0      4           349909  21.075   NaN        S         0     0
# 4      0      0  SOTON/OQ 392076   7.050   NaN        S         0     1

# %%
X = train_data[['Pclass', 'Sex2', 'Age',
       'SibSp', 'Parch', 'Fare']].values

# %%
Y = train_data[['Survived']].values

# %%
alg = LogisticRegression()
alg.fit(X, Y)
# Out:
# /home/arnab/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/arnab/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print("Coeff, m", alg.coef_)
print("Coeff, c", alg.intercept_)
# Out:
# Coeff, m [[-0.77641443 -2.4116804  -0.02745348 -0.28799466 -0.13824889  0.0048182 ]]
# Coeff, c [3.6794551]

# %%
y = alg.predict(X)

# %%
test_data.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       2                     Davies, Master. John Morgan Jr    male   8.0
# 1       1                        Leader, Dr. Alice (Farnham)  female  49.0
# 2       3                            Kilgannon, Mr. Thomas J    male   NaN
# 3       2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0
# 4       1                          McGough, Mr. James Robert    male  36.0
#
#    SibSp  Parch      Ticket     Fare Cabin Embarked
# 0      1      1  C.A. 33112  36.7500   NaN        S
# 1      0      0       17465  25.9292   D17        S
# 2      0      0       36865   7.7375   NaN        Q
# 3      2      1      243847  27.0000   NaN        S
# 4      0      0    PC 17473  26.2875   E25        S

# %%
test_data.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  223.000000  178.000000  223.000000  223.000000  223.000000
# mean     2.345291   29.694775    0.506726    0.304933   32.622551
# std      0.850047   15.398053    1.169700    0.634108   61.062047
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   19.250000    0.000000    0.000000    7.879200
# 50%      3.000000   27.000000    0.000000    0.000000   12.475000
# 75%      3.000000   37.750000    1.000000    0.000000   30.035400
# max      3.000000   71.000000    8.000000    2.000000  512.329200

# %%
test_data.Age.fillna(test_data.Age.mean(), inplace = True)

# %%
test_data.describe()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 10 columns):
# Pclass      223 non-null int64
# Name        223 non-null object
# Sex         223 non-null object
# Age         223 non-null float64
# SibSp       223 non-null int64
# Parch       223 non-null int64
# Ticket      223 non-null object
# Fare        223 non-null float64
# Cabin       50 non-null object
# Embarked    222 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 17.5+ KB

# %%
test_data['Sex2'] = le.fit_transform(test_data['Sex'])

# %%
test_data.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare        Sex2
# count  223.000000  223.000000  223.000000  223.000000  223.000000  223.000000
# mean     2.345291   29.694775    0.506726    0.304933   32.622551    0.672646
# std      0.850047   13.749153    1.169700    0.634108   61.062047    0.470303
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.879200    0.000000
# 50%      3.000000   29.694775    0.000000    0.000000   12.475000    1.000000
# 75%      3.000000   35.000000    1.000000    0.000000   30.035400    1.000000
# max      3.000000   71.000000    8.000000    2.000000  512.329200    1.000000

# %%
test_data.head()
# Out:
#    Pclass                                               Name     Sex  \
# 0       2                     Davies, Master. John Morgan Jr    male
# 1       1                        Leader, Dr. Alice (Farnham)  female
# 2       3                            Kilgannon, Mr. Thomas J    male
# 3       2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female
# 4       1                          McGough, Mr. James Robert    male
#
#          Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Sex2
# 0   8.000000      1      1  C.A. 33112  36.7500   NaN        S     1
# 1  49.000000      0      0       17465  25.9292   D17        S     0
# 2  29.694775      0      0       36865   7.7375   NaN        Q     1
# 3  24.000000      2      1      243847  27.0000   NaN        S     0
# 4  36.000000      0      0    PC 17473  26.2875   E25        S     1

# %%
X2 = test_data[['Pclass', 'Sex2', 'Age',
       'SibSp', 'Parch', 'Fare']].values

# %%
y_pred = alg.predict(X2)

# %%
np.savetxt("titanic_pred.csv",y_pred,delimiter=",",fmt="%0.5f")

# %%
alg.score
# Out:
# <bound method ClassifierMixin.score of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)>

# %%
print(alg.score)
# Out:
# <bound method ClassifierMixin.score of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)>
